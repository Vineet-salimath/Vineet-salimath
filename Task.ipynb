# %% [markdown]
# <a href="https://colab.research.google.com/github/Vineet-salimath/Vineet-salimath/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def login_check(username_input, password_input):
    correct_username = "admin"   #GIVEN CREDENTIALS
    correct_password = "1234"

    if username_input == correct_username and password_input == correct_password:
        print("Login Successful")
    else:
        print("Invalid Credentials")
login_check("admin", "1234")  #EXAMPLE
# Out:
# Login Successful

# %%
def analyze_results(marks):
    pass_count = 0
    fail_count = 0

    for i in marks:
        if i >= 50:
            pass_count += 1
        else:
            fail_count += 1

    print(f"Total Students Passed: {pass_count}")
    print(f"Total Students Failed: {fail_count}")

student_marks = [45, 78, 90, 33, 60]  #example
analyze_results(student_marks)
# Out:
# Total Students Passed: 3
# Total Students Failed: 2

# %%
def clean_names(names):
    cleaned = []
    for i in names:
        cleaned_name = i.strip().lower()  # remove spaces and convert to lowercase
        cleaned.append(cleaned_name)
    return cleaned
names_list = [" Peter ", "VIJAY", " Vineet "] #example
cleaned_list = clean_names(names_list)
print("Cleaned Names:", cleaned_list)
# Out:
# Cleaned Names: ['peter', 'vijay', 'vineet']

# %%
def message_analysis(messages):
    for msg in messages:
        length = len(msg)
        if length > 10:
            flag = " big message"
        else:
            flag = ""
        print("Message: '" + msg + "' | Length: " + str(length) + flag)

messages_list = ["Hi", "Welcome to the platform", "OK"] #example
message_analysis(messages_list)
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23 big message
# Message: 'OK' | Length: 2

# %%
def count_messages(logs, msg_type):
    count = logs.count(msg_type)
    print(msg_type + " messages:", count)

system_logs = ["INFO", "ERROR", "WARNING", "ERROR"]   #example
count_messages(system_logs, "ERROR")
# Out:
# ERROR messages: 2

# %% [markdown]
# Task 2 internship.

# %%
sentence = "My name is Vineet"  #example
words = sentence.split()
unique_words = set(words)

print(f"Unique words count: {len(unique_words)}")
print(f"Unique words: {unique_words}")
# Out:
# Unique words count: 4
# Unique words: {'is', 'name', 'Vineet', 'My'}

# %% [markdown]
# Problem 2

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

highest_salary = 0
top_employee = ""
for name, salary in employees.items():
     if salary > highest_salary:
        highest_salary = salary
        top_employee = name
print(f"Highest Salary: {top_employee} - {highest_salary}")
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# Problem 3

# %%
numbers = [45, 22, 89, 10, 66]
max_val = numbers[0]
min_val = numbers[0]

for num in numbers:

    if num > max_val:
        max_val = num


    if num < min_val:
        min_val = num

print(f"List: {numbers}")
print(f"Max: {max_val}")
print(f"Min: {min_val}")
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# Problem 4

# %%
prices = [450, 1200, 899, 1500, 300]
count = 0

for price in prices:
    if price > 1000:
        count += 1

print(f"Products above 1000: {count}")
# Out:
# Products above 1000: 2

# %% [markdown]
# Problem 5

# %%
attendance = ["P", "P", "A", "P", "P"]

present_days = attendance.count("P")
total_days = len(attendance)

percentage = (present_days / total_days) * 100

print(f"Attendance Percentage: {percentage}")
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# Problem 6

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]
unique_numbers = set(phone_numbers)
print(f"Unique phone numbers: {unique_numbers}")
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# Problem 7

# %%
text = "pythonptho"
frequency = {}
for char in text:
        frequency[char] = frequency.get(char, 0) + 1
print(frequency)
# Out:
# {'p': 2, 'y': 1, 't': 2, 'h': 2, 'o': 2, 'n': 1}

# %% [markdown]
# Problem 8

# %%
my_list = [10, 20, 30]
my_tuple = tuple(my_list)
print(f"Tuple: {my_tuple}")
# Out:
# Tuple: (10, 20, 30)

# %% [markdown]
# Problem 9

# %%
employee_data = {"Name": "Ravi", "ID": 101, "Role": "Intern"}
key_to_check = "Name","ID","Role"

if key_to_check in employee_data:
    print("Employee exists")
else:
    print("Employee not found")
# Out:
# Employee not found

# %% [markdown]
# Problem 10

# %%
marks = [80, 75, 60, 75]
average = sum(marks) / len(marks)
print(f"Average Marks: {average}")
# Out:
# Average Marks: 72.5

# %% [markdown]
# TASK 3

# %% [markdown]
# Problem 1

# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}
all_scores = list(employees.values())
highest_score = max(all_scores)
top_performers = []
for name, score in employees.items():
    if score == highest_score:
        top_performers.append(name)

names_string = ", ".join(top_performers)
print(f"Top Performers Eligible for Bonus: {names_string} (Score: {highest_score})")
print("\n")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# Problem 2

# %%
search_query = "Buy mobile phone buy phone online"
query_lower = search_query.lower()
#  Split the sentence into individual words
words = query_lower.split()
# Count frequency of each word using a dictionary
word_counts = {}
for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1
duplicates = {}
for word, count in word_counts.items():
    if count > 1:
        duplicates[word] = count
print(duplicates)
print("\n")
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# Problem 3

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
valid_readings = []

for hour_index, reading in enumerate(sensor_readings):
    if reading % 2 == 0:
        valid_readings.append((hour_index, reading))
print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
print("\n")
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# Problem 4

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"]

domain_counts = {}
total_emails = len(emails)

# Extract domain from each email
for email in emails:
    # Split the email at '@' and take the second part
    parts = email.split('@')
    domain = parts[1]
    if domain in domain_counts:
        domain_counts[domain] += 1
    else:
        domain_counts[domain] = 1
for domain, count in domain_counts.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {int(percentage)}%")

print("\n")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# Problem 5

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]
total_sales = sum(sales)
number_of_days = len(sales)
average_sales = total_sales / number_of_days

threshold = average_sales * 1.30

# Loop through sales to find spikes
for day, sale_value in enumerate(sales, start=1):
    if sale_value > threshold:
        print(f"Day {day}: {sale_value}")

print("\n")
# Out:
# Day 6: 3000

# %% [markdown]
# Problem 6

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
id_counts = {}
for user in user_ids:
    if user in id_counts:
        id_counts[user] += 1
    else:
        id_counts[user] = 1
for user, count in id_counts.items():
    if count > 1:
        print(f"{user} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times

# %% [markdown]
# TASk 4

# %% [markdown]
# Problem 1

# %%
def validate_recharge():
    valid_plans = [50,199, 299, 399, 599]
    while True:
        try:
            amount = int(input("Enter your recharge amount (₹): "))
        except ValueError:
            print("Please enter a valid number.")
            continue


        if amount < 50:
            print("Failed: Minimum recharge amount is ₹50. Please try again.")

        elif amount not in valid_plans:
            print(f"Failed: ₹{amount} is not a valid plan. Choose from {valid_plans}.")
        else:
            print("Success! Your recharge is being processed.")
            break

validate_recharge()
# Out:
# Enter your recharge amount (₹): 50
# Success! Your recharge is being processed.

# %% [markdown]
# Problem 2

# %%
def check_inventory(stock_data):

    for product_name, quantity in stock_data.items():
        if quantity < 15:
            print(f"{product_name} -> Reorder Alert (Only {quantity} left!)")
        else:
            print(f"{product_name} -> Stock OK ({quantity} available)")

warehouse_items = {
    "Laptops": 10,
    "Mice": 45,
    "Keyboards": 12,
    "Monitors": 20
}
check_inventory(warehouse_items)
# Out:
# Laptops -> Reorder Alert (Only 10 left!)
# Mice -> Stock OK (45 available)
# Keyboards -> Reorder Alert (Only 12 left!)
# Monitors -> Stock OK (20 available)

# %% [markdown]
# Problem 3

# %%
def process_result(marks_list):
    total_score = 0
    for mark in marks_list:
        total_score = total_score + mark
    number_of_subjects = len(marks_list)
    average_score = total_score / number_of_subjects

    print(f"Student Average: {average_score}")
    if average_score >= 50:
        return "Pass"
    else:
        return "Fail"
student_marks = [45, 60, 55, 40, 70]

print("Final Result:", process_result(student_marks))
# Out:
# Student Average: 54.0
# Final Result: Pass

# %% [markdown]
# Problem 4

# %%
def cab_fare_estimator():
    while True:
        distance = float(input("Enter distance (km): "))
        peak_hour = input("Is it peak hour? (yes/no): ").lower()
        fare = 50 + (12 * distance)
        if peak_hour == "yes":
            fare = fare + (fare * 0.25)
        print(f"Total Estimated Fare: ₹{fare}")
        retry = input("Calculate another fare? (yes/no): ").lower()
        if retry != "yes":
            print("Goodbye!")
            break
cab_fare_estimator()
# Out:
# Enter distance (km): 5.45
# Is it peak hour? (yes/no): no
# Total Estimated Fare: ₹115.4
# Calculate another fare? (yes/no): no
# Goodbye!

# %% [markdown]
# Problem 5

# %%
def check_eligibility(attendance_record):
    present_count = 0
    for status in attendance_record:
        if status == "P":
            present_count += 1


    total_days = len(attendance_record)
    attendance_percentage = (present_count / total_days) * 100

    print(f"Total Attendance: {attendance_percentage}%")


    if attendance_percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"


employee_attendance = ["P", "P", "A", "P", "P", "A", "P", "P", "P", "P"]

print("Employee Status:", check_eligibility(employee_attendance))
# Out:
# Total Attendance: 80.0%
# Employee Status: Eligible

# %% [markdown]
# Problem 6

# %%
def check_password_strength(password):
    if len(password) < 8:
        return "Weak: Password must be at least 8 characters long."
    has_digit = False
    has_special = False


    for char in password:
        if char.isdigit():
            has_digit = True
        if char in "@#$":
            has_special = True


    if has_digit and has_special:
        return "Strong: Password is secure!"
    elif not has_digit:
        return "Weak: Password needs at least one number."
    else:
        return "Weak: Password needs at least one special character (@, #, or $)."

#print(check_password_strength("password123"))  # Weak
print(check_password_strength("SecureP@ssw0rd"))  # Strong
# Out:
# Strong: Password is secure!

# %% [markdown]
# TASK 5

# %% [markdown]
# Problem 1

# %%
def analyze_engagement(likes_list):
    total_likes = 0
    for likes in likes_list:
        total_likes += likes
    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    print(f"Total Likes: {total_likes}")
    print(f"Post Status: {status}\n")
user_input = input("Enter the likes")
likes_list = list(map(int, user_input.split()))
analyze_engagement(likes_list)
# Out:
# Enter the likes1500
# Total Likes: 1500
# Post Status: Viral Post

# %% [markdown]
# Problem 2

# %%
def check_medicine_stock(stock):

    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"

    print(f"Medicine Stock: {stock}")
    print(f"Status: {status}\n")
check_medicine_stock(10)
check_medicine_stock(8)
# Out:
# Medicine Stock: 10
# Status: Stock Sufficient
#
# Medicine Stock: 8
# Status: Low Stock Alert

# %% [markdown]
# Problem 3

# %%
def check_rainfall_adequacy(rainfall_list, required_level):
    total_rainfall = 0
    for rain in rainfall_list:
        total_rainfall += rain
    avg_rainfall = total_rainfall / len(rainfall_list)

    if avg_rainfall >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"
    print(f"Average Rainfall: {int(avg_rainfall)}")
    print(f"Rainfall Status: {status}")

check_rainfall_adequacy([70, 74, 72, 72], 70)
# Out:
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# Problem 4

# %%
def detect_duplicate_accounts(usernames):
    unique_users = set(usernames)
    if len(unique_users) < len(usernames):
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")
detect_duplicate_accounts(["john_doe", "jane_smith", "john_doe"])
detect_duplicate_accounts(["john_doe", "jane_smith"])
# Out:
# Duplicate Accounts Found: Yes
# Duplicate Accounts Found: No

# %% [markdown]
# Problem 5

# %%
def check_appointment_eligibility(age):
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print(f"Patient Age: {age}")
    print(f"Eligibility Status: {status}")
check_appointment_eligibility(17)
check_appointment_eligibility(21)
# Out:
# Patient Age: 17
# Eligibility Status: Not Eligible
# Patient Age: 21
# Eligibility Status: Eligible

# %% [markdown]
# Problem 6

# %%
def filter_premium_crops(prices):
    premium_crops = []
    for price in prices:
        if price > 2000:
            premium_crops.append(price)
    print(f"Premium Crops: {premium_crops}")

filter_premium_crops([1500, 2500, 1800, 3200])
# Out:
# Premium Crops: [2500, 3200]

# %% [markdown]
# Problem 7

# %%
def check_application_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    print(f"Error Count: {errors}")
    print(f"System Status: {status}")
check_application_health(10)
check_application_health(0)
check_application_health(4)
# Out:
# Error Count: 10
# System Status: Critical Issues
# Error Count: 0
# System Status: Healthy
# Error Count: 4
# System Status: Minor Issues

# %% [markdown]
# Problem 8

# %%
def check_transaction_limit(amount):
    daily_limit = 50000
    if amount <= daily_limit:
        status = "Approved"
    else:
        status = "Rejected"

    print(f"Transaction Amount: {amount}")
    print(f"Transaction Status: {status}")
check_transaction_limit(40000)
check_transaction_limit(60000)
# Out:
# Transaction Amount: 40000
# Transaction Status: Approved
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# Problem 9

# %%
def check_attendance_eligibility(attendance_list):
    days_present = 0
    for day in attendance_list:
        if day == "Present":
            days_present += 1
    percentage = (days_present / len(attendance_list)) * 100

    if percentage >= 75:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print(f"Attendance Percentage: {percentage}")
    print(f"Exam Eligibility: {status}")
check_attendance_eligibility(["Present"] * 8 + ["Absent"] * 2)
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# Problem 10

# %%
def analyze_electricity_bill(units):
    bill = 0
    if units <= 100:
        bill = units * 3
    elif units <= 200:
        bill = (100 * 3) + ((units - 100) * 5)
    else:
        bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

    if bill < 500:
        usage = "Low Usage"
    elif bill < 1500:
        usage = "Moderate Usage"
    else:
        usage = "High Usage"

    return bill, usage
total_bill, usage_status = analyze_electricity_bill(250)
print(f"Electricity Bill: ₹{total_bill}")
print(f"Usage Class: {usage_status}")
# Out:
# Electricity Bill: ₹1150
# Usage Class: Moderate Usage
